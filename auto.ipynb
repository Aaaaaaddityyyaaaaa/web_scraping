# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
# %matplotlib inline

# %%
df = pd.read_csv("auto.csv")

# %%
df.columns = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]

# %%
df.shape
# Out:
# (204, 26)

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
df.replace("?", np.nan , inplace= True)

# %%
df["price"] = pd.to_numeric(df["price"].astype(str),errors="coerce")

# %%
df["bore"] =  pd.to_numeric(df["bore"].astype(str),errors="coerce")  
df["stroke"] =  pd.to_numeric(df["stroke"].astype(str),errors="coerce")  
df["peak-rpm"] =  pd.to_numeric(df["peak-rpm"].astype(str),errors="coerce")  
df["horsepower"] =  pd.to_numeric(df["horsepower"].astype(str),errors="coerce")  
df["normalized-losses"] =  pd.to_numeric(df["normalized-losses"].astype(str),errors="coerce")

# %%
df.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                NaN  alfa-romero       gas        std
# 1          1                NaN  alfa-romero       gas        std
# 2          2              164.0         audi       gas        std
# 3          2              164.0         audi       gas        std
# 4          2                NaN         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two    hatchback          rwd           front        94.5  ...
# 2         four        sedan          fwd           front        99.8  ...
# 3         four        sedan          4wd           front        99.4  ...
# 4          two        sedan          fwd           front        99.8  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses    float64
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# dtype: object

# %%
df["bore"].unique()
# Out:
# array([3.47, 2.68, 3.19, 3.13, 3.5 , 3.31, 3.62, 2.91, 3.03, 2.97, 3.34,
#        3.6 , 2.92, 3.15, 3.43, 3.63, 3.54, 3.08,  nan, 3.39, 3.76, 3.58,
#        3.46, 3.8 , 3.78, 3.17, 3.35, 3.59, 2.99, 3.33, 3.7 , 3.61, 3.94,
#        3.74, 2.54, 3.05, 3.27, 3.24, 3.01])

# %%
df['bore'] = pd.to_numeric(df['bore'], errors='coerce')
df['stroke'] = pd.to_numeric(df['bore'], errors='coerce')
df['peak-rpm'] = pd.to_numeric(df['bore'], errors='coerce')
df['horsepower'] = pd.to_numeric(df['bore'], errors='coerce')
df['normalized-losses'] = pd.to_numeric(df['normalized-losses'], errors='coerce')

# %%
df['bore'] = df['bore'].replace(np.nan,df["bore"].mean())
df['stroke'] = df['stroke'].replace(np.nan,df["stroke"].mean())
df['peak-rpm'] = df['peak-rpm'].replace(np.nan,df["peak-rpm"].mean())
df['horsepower'] = df['horsepower'].replace(np.nan,df["horsepower"].mean())
df['normalized-losses'] = df['normalized-losses'].replace(np.nan,df["normalized-losses"].mean())

# %%
df['num-of-doors'] = df['num-of-doors'].replace(np.nan,df["num-of-doors"].mode()[0])

# %%
df.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3              122.0  alfa-romero       gas        std
# 1          1              122.0  alfa-romero       gas        std
# 2          2              164.0         audi       gas        std
# 3          2              164.0         audi       gas        std
# 4          2              122.0         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two    hatchback          rwd           front        94.5  ...
# 2         four        sedan          fwd           front        99.8  ...
# 3         four        sedan          4wd           front        99.4  ...
# 4          two        sedan          fwd           front        99.8  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %%
df.describe()
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  204.000000         204.000000  204.000000  204.000000  204.000000
# mean     0.823529         122.000000   98.806373  174.075000   65.916667
# std      1.239035          31.758944    5.994144   12.362123    2.146716
# min     -2.000000          65.000000   86.600000  141.100000   60.300000
# 25%      0.000000         101.000000   94.500000  166.300000   64.075000
# 50%      1.000000         122.000000   97.000000  173.200000   65.500000
# 75%      2.000000         137.000000  102.400000  183.200000   66.900000
# max      3.000000         256.000000  120.900000  208.100000   72.300000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  204.000000   204.000000   204.000000  204.000000  204.000000
# mean    53.749020  2555.602941   126.892157    3.329050    3.329050
# std      2.424901   521.960820    41.744569    0.271331    0.271331
# ...

# %%
from sklearn.preprocessing import MinMaxScaler , OneHotEncoder , LabelEncoder

# %%
mmscaler = MinMaxScaler()

# %%
df[["symboling","normalized-losses","wheel-base","length","width","height","curb-weight","engine-size","bore","stroke","compression-ratio","horsepower","peak-rpm","city-mpg","highway-mpg","price"]] = mmscaler.fit_transform(df[["symboling","normalized-losses","wheel-base","length","width","height","curb-weight","engine-size","bore","stroke","compression-ratio","horsepower","peak-rpm","city-mpg","highway-mpg","price"]])

# %%
df.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0        1.0           0.298429  alfa-romero       gas        std
# 1        0.6           0.298429  alfa-romero       gas        std
# 2        0.8           0.518325         audi       gas        std
# 3        0.8           0.518325         audi       gas        std
# 4        0.8           0.298429         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front    0.058309  ...
# 1          two    hatchback          rwd           front    0.230321  ...
# 2         four        sedan          fwd           front    0.384840  ...
# 3         four        sedan          4wd           front    0.373178  ...
# 4          two        sedan          fwd           front    0.384840  ...
#
#    engine-size  fuel-system      bore    stroke compression-ratio horsepower  \
# ...

# %%
import seaborn as sns

# %%
sns.regplot(x=df["engine-size"] , y = df["price"])
# Out:
# <Axes: xlabel='engine-size', ylabel='price'>

# %%
sns.boxplot(x=df["num-of-doors"],y=df["price"])
# Out:
# <Axes: xlabel='num-of-doors', ylabel='price'>

# %%
df_avg=df.groupby(["body-style","drive-wheels"],as_index=False)['price'].mean()

# %%
df_avg.pivot_table(values="price" ,index="body-style" , columns="drive-wheels")
# Out:
# drive-wheels       4wd       fwd       rwd
# body-style
# convertible        NaN  0.160791  0.532378
# hardtop            NaN  0.077727  0.473778
# hatchback     0.061690  0.081386  0.228881
# sedan         0.186916  0.116524  0.411942
# wagon         0.098748  0.121129  0.294827

# %%
df[["stroke","price"]].corr()
# Out:
#           stroke     price
# stroke  1.000000  0.543433
# price   0.543433  1.000000

# %%
sns.regplot(x=df["stroke"] , y=df["price"])
# Out:
# <Axes: xlabel='stroke', ylabel='price'>

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
df= df.dropna()

# %%
lr.fit(df[["engine-size"]],df["price"])
# Out:
# LinearRegression()

# %%
ypred = lr.predict(df[["engine-size"]])

# %%
yresidual = df["price"]-ypred

# %%
sns.residplot(x=ypred,y=yresidual)
# Out:
# <Axes: ylabel='price'>

# %%
sns.kdeplot(df["price"], color='r', label='Actual')
sns.kdeplot(ypred, color='b', label='Fitted')
# Out:
# <Axes: xlabel='price', ylabel='Density'>

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import Pipeline

# %%
sns.regplot(x=df["engine-size"] , y=df["price"])
# Out:
# <Axes: xlabel='engine-size', ylabel='price'>

# %%
sns.regplot(x=df["normalized-losses"],y=df["price"])
# Out:
# <Axes: xlabel='normalized-losses', ylabel='price'>

# %%
df_num = df.select_dtypes(exclude="object")

# %%
df_num.dtypes
# Out:
# symboling            float64
# normalized-losses    float64
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight          float64
# engine-size          float64
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg             float64
# highway-mpg          float64
# price                float64
# dtype: object

# %%
df_cat = df.select_dtypes(include="object")

# %%
df_cat.dtypes
# Out:
# make                object
# fuel-type           object
# aspiration          object
# num-of-doors        object
# body-style          object
# drive-wheels        object
# engine-location     object
# engine-type         object
# num-of-cylinders    object
# fuel-system         object
# dtype: object

# %%
df_num=df_num.drop(labels=["price"] ,axis=1)

# %%
y= df["price"]

# %%
poly = PolynomialFeatures(degree=2)
df_poly = poly.fit_transform(X=df_num)

# %%
lmpoly.score(df_poly,y)
# Out:
# 0.968826773246498

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain , xtest , ytrain ,ytest = train_test_split(df_num,y,train_size=0.6 ,random_state=420)

# %%
lmpoly = LinearRegression()

# %%
lmpoly.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
lmpoly.score(xtest,ytest)
# Out:
# 0.8244336522703087

# %%
lmpoly.score(xtrain,ytrain)
# Out:
# 0.7894150980924219

# %%
ohe =OneHotEncoder()

# %%
df_ohe_cat = ohe.fit_transform(df_cat)

# %%
df_ohe_cat = df_ohe_cat.toarray()

# %%
xnums = np.array(df_num)
x = np.hstack([xnums,df_ohe_cat])

# %%
x
# Out:
# array([[1.        , 0.29842932, 0.05830904, ..., 1.        , 0.        ,
#         0.        ],
#        [0.6       , 0.29842932, 0.2303207 , ..., 1.        , 0.        ,
#         0.        ],
#        [0.8       , 0.51832461, 0.38483965, ..., 1.        , 0.        ,
#         0.        ],
#        ...,
#        [0.2       , 0.15706806, 0.65597668, ..., 1.        , 0.        ,
#         0.        ],
#        [0.2       , 0.15706806, 0.65597668, ..., 0.        , 0.        ,
#         0.        ],
#        [0.2       , 0.15706806, 0.65597668, ..., 1.        , 0.        ,
#         0.        ]])

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV

# %%
pipeline =Pipeline([('poly' , PolynomialFeatures()),("ridge",Ridge())])

# %%
xtrain , xtest , ytrain ,ytest  = train_test_split(x,y,train_size=0.7 , random_state=42)

# %%
parameters = [{ "poly__degree" : [1,2,3],
    "ridge__alpha":[0.01,0.1,0.5,1]}]

# %%
grid = GridSearchCV(pipeline,parameters,cv=3,scoring="r2",n_jobs=-1)

# %%
grid.fit(xtrain,ytrain)
# Out:
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('poly', PolynomialFeatures()),
#                                        ('ridge', Ridge())]),
#              n_jobs=-1,
#              param_grid=[{'poly__degree': [1, 2, 3],
#                           'ridge__alpha': [0.01, 0.1, 0.5, 1]}],
#              scoring='r2')

# %%
best_model = grid.best_estimator_

# %%
best_model.score(xtrain,ytrain)
# Out:
# 0.9954873487147186

# %%
best_model.score(xtest,ytest)
# Out:
# 0.9454671625557416

# %%
best_model.get_params()
# Out:
# {'memory': None,
#  'steps': [('poly', PolynomialFeatures(degree=3)),
#   ('ridge', Ridge(alpha=0.5))],
#  'transform_input': None,
#  'verbose': False,
#  'poly': PolynomialFeatures(degree=3),
#  'ridge': Ridge(alpha=0.5),
#  'poly__degree': 3,
#  'poly__include_bias': True,
#  'poly__interaction_only': False,
#  'poly__order': 'C',
#  'ridge__alpha': 0.5,
#  'ridge__copy_X': True,
#  'ridge__fit_intercept': True,
#  'ridge__max_iter': None,
#  'ridge__positive': False,
#  'ridge__random_state': None,
#  'ridge__solver': 'auto',
#  'ridge__tol': 0.0001}

# %%
ypred = best_model.predict(xtest)
yresd = ytest-ypred

# %%
sns.residplot(x=ytest , y=ypred)
# Out:
# <Axes: xlabel='price'>

# %%
sns.kdeplot(x=ypred , color='red' , label="predicted")
sns.kdeplot(x=ytest ,color='blue', label="original")
plt.legend()
