# %%
import sqlite3 
import prettytable as pt
pt.DEFAULT = pt.MARKDOWN
# Out:
# C:\Users\Aditya Pandey\AppData\Local\Temp\ipykernel_6936\1442380963.py:3: DeprecationWarning: the 'MARKDOWN' constant is deprecated, use the 'TableStyle' enum instead
#   pt.DEFAULT = pt.MARKDOWN

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
con  = sqlite3.connect("Chicago.db")

# %%
# %sql sqlite:///Chicago.db

# %%
# %%sql
# SELECT name
# FROM sqlite_master
# WHERE type='table';
# Out:
#  * sqlite:///Chicago.db
#    sqlite:///Insructor.db
# Done.
# [('census',), ('crime',), ('school',)]

# %%
# %%sql
# select * from school limit 1
# Out:
#  * sqlite:///Chicago.db
#    sqlite:///Insructor.db
# Done.
# [(0, 610038, 'Abraham Lincoln Elementary School', 'ES', '615 W Kemper Pl', 'Chicago', 'IL', 60614, '(773) 534-5720', 'http://schoolreports.cps.edu/SchoolProgressReport_Eng/Spring2011Eng_610038.pdf', 'Fullerton Elementary Network', 'NORTH-NORTHWEST SIDE COLLABORATIVE', 'No', 'Standard', 'Not on Probation', 'Level 1', 'Yes', 'Very Strong', 99.0, 'Very Strong', '99', 'Strong', 74.0, 'Strong', 66.0, 'Weak', '65', 'Strong', '70', 'Strong', '56', 'Average', '47', '96.00%', 2.0, '96.40%', '95.80%', '80.1', '43.3', '89.6', '84.9', '60.7', '62.6', '81.9', '85.2', '52', '62.4', '66.3', '77.9', 69.7, 64.4, 0.2, 0.9, 'Yellow', 'Green', '67.1', '54.5', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 813, 33, 'NDA', 1171699.458, 1915829.428, 41.92449696, -87.64452163, 7, 'LINCOLN PARK', 43, 18, '(41.92449696, -87.64452163)')]

# %%
# %%sql
# create view School_view (School_id, Name_of_school , Street_Address, City)
# as select School_id , Name_of_school , Street_Address, City from
# school
# Out:
#  * sqlite:///Chicago.db
#    sqlite:///Insructor.db
# Done.
# []

# %%
# %%sql
# select count(School_ID) , School_ID from School_view group by School_ID order by School_ID
# Out:
#  * sqlite:///Chicago.db
#    sqlite:///Insructor.db
# Done.
# [(1, 400018),
#  (1, 609674),
#  (1, 609676),
#  (1, 609678),
#  (1, 609679),
#  (1, 609680),
#  (1, 609682),
#  (1, 609691),
#  (1, 609692),
#  (1, 609693),
#  (1, 609694),
#  (1, 609695),
#  (1, 609698),
#  (1, 609702),
#  (1, 609704),
#  (1, 609705),
#  (1, 609707),
#  (1, 609708),
#  (1, 609709),
#  (1, 609710),
#  (1, 609711),
#  (1, 609712),
#  (1, 609713),
#  (1, 609715),
#  (1, 609716),
#  (1, 609718),
#  (1, 609719),
#  (1, 609720),
#  (1, 609722),
#  (1, 609723),
#  (1, 609724),
#  (1, 609725),
#  (1, 609726),
#  (1, 609727),
#  (1, 609728),
#  (1, 609729),
#  (1, 609730),
#  (1, 609732),
#  (1, 609733),
#  (1, 609734),
#  (1, 609735),
#  (1, 609736),
#  (1, 609737),
#  (1, 609738),
#  (1, 609739),
#  (1, 609740),
#  (1, 609741),
#  (1, 609744),
#  (1, 609745),
#  (1, 609746),
#  (1, 609749),
#  (1, 609751),
#  (1, 609753),
#  (1, 609754),
#  (1, 609755),
#  (1, 609756),
#  (1, 609759),
#  (1, 609760),
# ...
