# %%
pip install beautifulsoup4
# Out:
# ...
#
#    ---------------------------------------- 2/2 [beautifulsoup4]
#
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
request  = requests.get("https://www.skoda-auto.co.in/models/range")

# %%
request.status_code
# Out:
# 200

# %%
html = request.text

# %%
beautyObj = BeautifulSoup(html , "html.parser" )

# %%
print(beautyObj.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en-IN" xml:lang="en-IN" xmlns="http://www.w3.org/1999/xhtml">
#  <head prefix="og: http://ogp.me/ns#">
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <title>
#    ŠKODA Cars in India | ŠKODA India
#   </title>
#   <meta content="Explore the wide range of cars in India by ŠKODA, with a variety of options and equipped with latest features. Get the right vehicle for your need." name="description"/>
#   <meta content="skoda cars, skoda cars in india, skoda models range" name="keywords"/>
#   <meta content="index, follow" name="robots"/>
#   <meta content="website" property="og:type"/>
#   <meta content="https://www.skoda-auto.co.in/models/range" property="og:url"/>
#   <meta content="ŠKODA Cars in India | ŠKODA India" property="og:title"/>
# ...
